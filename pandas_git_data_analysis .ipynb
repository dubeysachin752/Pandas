# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv'

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   Package        Item                                         Title  Rows  \
# 0    boot        acme                        Monthly Excess Returns    60
# 1    boot        aids  Delay in AIDS Reporting in England and Wales   570
# 2    boot   aircondit        Failures of Air-conditioning Equipment    12
# 3    boot  aircondit7        Failures of Air-conditioning Equipment    24
# 4    boot        amis                Car Speeding and Warning Signs  8437
#
#    Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0     3         0            1         0          0          2
# 1     6         1            0         0          0          6
# 2     1         0            0         0          0          1
# 3     1         0            0         0          0          1
# 4     4         1            0         0          0          4
#
#                                                  CSV  \
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...
# 2  https://vincentarelbundock.github.io/Rdatasets...
# 3  https://vincentarelbundock.github.io/Rdatasets...
# 4  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                  Doc
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...
# 2  https://vincentarelbundock.github.io/Rdatasets...
# 3  https://vincentarelbundock.github.io/Rdatasets...
# 4  https://vincentarelbundock.github.io/Rdatasets...

# %%
df.tail()
# Out:
#      Package          Item                                 Title  Rows  Cols  \
# 1298     vcd      UKSoccer                      UK Soccer Scores    25     3
# 1299     vcd  VisualAcuity  Visual Acuity in Left and Right Eyes    32     4
# 1300     vcd       VonBort      Von Bortkiewicz Horse Kicks Data   280     4
# 1301     vcd    WeldonDice                    Weldon's Dice Data    11     2
# 1302     vcd    WomenQueue                       Women in Queues    11     2
#
#       n_binary  n_character  n_factor  n_logical  n_numeric  \
# 1298         0            0         2          0          1
# 1299         1            0         3          0          1
# 1300         1            0         2          0          2
# 1301         0            0         1          0          1
# 1302         0            0         1          0          1
#
#                                                     CSV  \
# 1298  https://vincentarelbundock.github.io/Rdatasets...
# 1299  https://vincentarelbundock.github.io/Rdatasets...
# 1300  https://vincentarelbundock.github.io/Rdatasets...
# 1301  https://vincentarelbundock.github.io/Rdatasets...
# 1302  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                     Doc
# 1298  https://vincentarelbundock.github.io/Rdatasets...
# 1299  https://vincentarelbundock.github.io/Rdatasets...
# 1300  https://vincentarelbundock.github.io/Rdatasets...
# 1301  https://vincentarelbundock.github.io/Rdatasets...
# 1302  https://vincentarelbundock.github.io/Rdatasets...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df['CSV']
# Out:
# 0       https://vincentarelbundock.github.io/Rdatasets...
# 1       https://vincentarelbundock.github.io/Rdatasets...
# 2       https://vincentarelbundock.github.io/Rdatasets...
# 3       https://vincentarelbundock.github.io/Rdatasets...
# 4       https://vincentarelbundock.github.io/Rdatasets...
#                               ...
# 1298    https://vincentarelbundock.github.io/Rdatasets...
# 1299    https://vincentarelbundock.github.io/Rdatasets...
# 1300    https://vincentarelbundock.github.io/Rdatasets...
# 1301    https://vincentarelbundock.github.io/Rdatasets...
# 1302    https://vincentarelbundock.github.io/Rdatasets...
# Name: CSV, Length: 1303, dtype: object

# %%
df['Doc']
# Out:
# 0       https://vincentarelbundock.github.io/Rdatasets...
# 1       https://vincentarelbundock.github.io/Rdatasets...
# 2       https://vincentarelbundock.github.io/Rdatasets...
# 3       https://vincentarelbundock.github.io/Rdatasets...
# 4       https://vincentarelbundock.github.io/Rdatasets...
#                               ...
# 1298    https://vincentarelbundock.github.io/Rdatasets...
# 1299    https://vincentarelbundock.github.io/Rdatasets...
# 1300    https://vincentarelbundock.github.io/Rdatasets...
# 1301    https://vincentarelbundock.github.io/Rdatasets...
# 1302    https://vincentarelbundock.github.io/Rdatasets...
# Name: Doc, Length: 1303, dtype: object
